# %%
###These are the same commands , though executed to a csv file.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df=pd.read_csv('finaccess2024_datasprint.csv')

##Getting the number of rows and columns
print("=" *20)
print("SHAPE")
print("="*20)
print(f"Rows:{df.shape[0]},Columns:{df.shape[1]}")

##Checking for data types
print("\n"+"="*20)
print("COLUMNS AND DATA TYPES")
print("="+"="*20)
print(df.dtypes.to_string())


#First and Last few rows
print("\n"+"=" *20)
print("FIRST 5 ROWS")
print("="*20)
print(df.head(5).to_string())

print("\n"+"=" *20)
print("FIRST 5 ROWS")
print("="*20)
print(df.tail().to_string())


##Basic statistics
print("\n"+"=" *20)
print("Basic Statistics")
print("=" *20)
print(df.describe().to_string())

##Missing Values
print("\n"+"=" *20)
print("MISSING VALUES")
print("=" *20)
missing = df.isnull().sum()
missing_pct =(df.isnull().mean()*100).round(2)
missing_df=pd.DataFrame({"Count":missing, "Percent":missing_pct})
print(missing_df[missing_df["Count"] > 0].sort_values("Percent", ascending=False).to_string())
if missing_df[missing_df["Count"]>0].empty:
    print("No missing values!")

##Checking for duplicate rows
print("\n"+"=" *20)
print("DUPLICATES")
print("=" *20)
print(f"Duplicate rows:{df.duplicated().sum}") 

##Checking for unique values
print("\n"+"=" *20)
print("Unique values per categorical column")
print("=" *20)
for col in df.select_dtypes(include=['object','category']).columns:
    print(f"\n---{col} ({df[col].nunique()} unique)-----")
    print(df[col].value_counts().head(10).to_string())



print("\n"+"="*20)
print("Numerical Values- Distributions")
print("="*20)
for col in df.select_dtypes(include=[np.number]).columns:
    print(f"\n---{col}---")
    print(f"Min: {df[col].min} \n Max: {df[col].max()}, \n Mean: {df[col].mean():.2f}, \n Median: {df[col].median():.2f} , \n Std: {df[col].std():.2f}")

##Checking for target variable
print("\n"+"="*20)
print("TARGET VARIABLE:financial_status")
print("="*20)
if "financial status" in df.columns:
    print(df["financial_status"].value_counts())
    print(df["financial_status"].value_counts(normalize=True).round(3)*100)
else:
    print("Column 'financial_status' not found")
    print("Available columns:",list(df.columns))
# Out:
# ====================
# SHAPE
# ====================
# Rows:20871,Columns:28
#
# ====================
# COLUMNS AND DATA TYPES
# =====================
# county                   object
# location_type            object
# Sex                      object
# Age                      object
# household_size            int64
# education_level          object
# marital_status           object
# monthly_income            int64
# Savings_formal           object
# Savings_informal         object
# Loan_formal              object
# Loan_informal            object
# defaulted                object
# formal_service_use       object
# mobile_money_access      object
# barriers_mobile_money    object
# mobile_ownership_1       object
# experienced_shock        object
# nfhi_11                  object
# nfhi_12                  object
# nfhi_13                  object
# accessto_13k_1month      object
# not_difficult            object
# financial_status         object
# fl_score                 object
# prodsum1                  int64
# barriers_bank            object
# has_disability           object
#
# ====================
# FIRST 5 ROWS
# ====================
#      county location_type     Sex       Age  household_size                                      education_level               marital_status  monthly_income Savings_formal Savings_informal Loan_formal Loan_informal defaulted formal_service_use mobile_money_access barriers_mobile_money mobile_ownership_1 experienced_shock nfhi_11 nfhi_12 nfhi_13 accessto_13k_1month not_difficult financial_status     fl_score  prodsum1  barriers_bank      has_disability
# 0   Garissa         Urban  Female     26-35               5  Completed technical training after secondary school  Married/Living with partner           30000      Non-usage        Non-usage   Non-usage         Usage        No              Usage                 Yes                     0                Yes                No     Yes     Yes     Yes                 Yes            No  Stayed the same  All correct         3            NaN  Without Disability
# 1   Garissa         Urban  Female  Above 55              11                                              "None "  Married/Living with partner           10000      Non-usage        Non-usage   Non-usage     Non-usage        No              Usage                 Yes                     0                Yes                No      No      No     Yes                  No            No         Worsened  Two correct         1  Affordability  Without Disability
# 2     Busia         Urban  Female     26-35               2                                  "Primary completed"           Divorced/separated            3000          Usage            Usage   Non-usage     Non-usage        No              Usage                 Yes                     0                Yes               Yes     Yes      No      No                  No            No         Improved  All correct         5  Affordability  Without Disability
# 3    Kiambu         Urban    Male     18-25               1                                     "Some secondary"         Single/Never Married           10000          Usage        Non-usage       Usage         Usage       Yes              Usage                 Yes                     0                Yes                No      No      No      No                 Yes            No         Improved  All correct         4  Affordability  Without Disability
# 4  Murang'a         Urban  Female     18-25               1       Some technical training after secondary school         Single/Never Married           10000          Usage        Non-usage       Usage     Non-usage        No              Usage                 Yes                     0                Yes                No     Yes     Yes     Yes                 Yes           Yes         Improved  All correct         5            NaN  Without Disability
#
# ====================
# FIRST 5 ROWS
# ====================
#              county location_type     Sex       Age  household_size      education_level               marital_status  monthly_income Savings_formal Savings_informal Loan_formal Loan_informal defaulted formal_service_use mobile_money_access barriers_mobile_money mobile_ownership_1 experienced_shock nfhi_11 nfhi_12 nfhi_13 accessto_13k_1month not_difficult financial_status      fl_score  prodsum1  barriers_bank      has_disability
# 20866         Wajir         Rural  Female     36-45               8              "None "  Married/Living with partner            6600      Non-usage        Non-usage   Non-usage         Usage        No              Usage                 Yes                     0                Yes                No     Yes     Yes     Yes                 Yes           Yes         Improved   One correct         2      Awareness  Without Disability
# 20867  Nairobi City         Urban  Female     18-25               4     "Some secondary"  Married/Living with partner           10000          Usage        Non-usage   Non-usage         Usage        No              Usage                 Yes                     0                Yes                No     Yes     Yes     Yes                  No            No         Worsened   Two correct         3  Affordability  Without Disability
# 20868          Embu         Rural    Male  Above 55               6      "Some primary "                      Widowed            6000      Non-usage        Non-usage   Non-usage         Usage       Yes              Usage                 Yes                     0                Yes                No      No     Yes     Yes                  No            No  Stayed the same  None correct         4            NaN  Without Disability
# 20869  Taita-Taveta         Urban  Female     26-35               7  "Primary completed"         Single/Never Married           13000          Usage        Non-usage       Usage         Usage       Yes              Usage                 Yes                     0                Yes                No      No     Yes      No                  No            No  Stayed the same   All correct         6  Affordability  Without Disability
# 20870         Kisii         Rural  Female  Above 55               3      "Some primary "  Married/Living with partner            5000      Non-usage        Non-usage   Non-usage     Non-usage        No          Non-usage                  No          Line blocked                 No               Yes      No      No     Yes                  No            No         Worsened   One correct         0      Awareness     With Disability
#
# ====================
# Basic Statistics
# ====================
#        household_size  monthly_income      prodsum1
# count    20871.000000    20871.000000  20871.000000
# mean         4.215946     9702.774280      3.936563
# std          2.512658    15423.366592      3.227992
# min          1.000000      100.000000      0.000000
# 25%          2.000000     2500.000000      1.000000
# 50%          4.000000     5000.000000      3.000000
# 75%          6.000000    10000.000000      6.000000
# max         20.000000   200000.000000     22.000000
#
# ====================
# MISSING VALUES
# ====================
#                Count  Percent
# barriers_bank   5734    27.47
#
# ====================
# DUPLICATES
# ====================
# Duplicate rows:<bound method Series.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20866    False
# 20867    False
# 20868    False
# 20869    False
# 20870    False
# Length: 20871, dtype: bool>
#
# ====================
# Unique values per categorical column
# ====================
#
# ---county (47 unique)-----
# county
# Meru            637
# Nairobi City    622
# Kakamega        601
# Nakuru          572
# Uasin Gishu     551
# Kiambu          541
# Migori          531
# Kilifi          530
# Bomet           530
# Kisumu          526
#
# ---location_type (2 unique)-----
# location_type
# Rural    13549
# Urban     7322
#
# ---Sex (2 unique)-----
# Sex
# Female    12326
# Male       8545
#
# ---Age (6 unique)-----
# Age
# 26-35       5361
# 18-25       3997
# 36-45       3942
# Above 55    3905
# 46-55       2545
# 16-17       1121
#
# ---education_level (13 unique)-----
# education_level
# "Secondary completed "                                 4113
# "Primary completed"                                    3953
# "Some primary "                                        3731
# "None "                                                3078
# "Some secondary"                                       2731
# Completed technical training after secondary school    1421
# "University completed "                                 988
# Some technical training after secondary school          501
# Some university                                         346
# "Refused to Answer (DO NOT READ OUT)"                     3
#
# ---marital_status (6 unique)-----
# marital_status
# Married/Living with partner           11432
# Single/Never Married                   5770
# Widowed                                2233
# Divorced/separated                     1427
# Don't know   (DO NOT READ OUT)            5
# Refused to Answer(DO NOT READ OUT)        4
#
# ---Savings_formal (2 unique)-----
# Savings_formal
# Non-usage    11635
# Usage         9236
#
# ---Savings_informal (2 unique)-----
# Savings_informal
# Non-usage    16031
# Usage         4840
#
# ---Loan_formal (2 unique)-----
# Loan_formal
# Non-usage    12340
# Usage         8531
#
# ---Loan_informal (2 unique)-----
# Loan_informal
# Non-usage    12604
# Usage         8267
#
# ---defaulted (2 unique)-----
# defaulted
# No     13920
# Yes     6951
#
# ---formal_service_use (2 unique)-----
# formal_service_use
# Usage        18224
# Non-usage     2647
#
# ---mobile_money_access (2 unique)-----
# mobile_money_access
# Yes    17868
# No      3003
#
# ---barriers_mobile_money (10 unique)-----
# barriers_mobile_money
# 0                        16409
# Phone ownership           2398
# Eligibility                996
# Affordability              434
# Line blocked               231
# Other                      135
# Relevance/Suitability      124
# Awareness                  108
# Service quality             18
# Trust                       18
#
# ---mobile_ownership_1 (2 unique)-----
# mobile_ownership_1
# Yes    16888
# No      3983
#
# ---experienced_shock (2 unique)-----
# experienced_shock
# No     11785
# Yes     9086
#
# ---nfhi_11 (2 unique)-----
# nfhi_11
# Yes    10744
# No     10127
#
# ---nfhi_12 (2 unique)-----
# nfhi_12
# Yes    12887
# No      7984
#
# ---nfhi_13 (2 unique)-----
# nfhi_13
# Yes    13151
# No      7720
#
# ---accessto_13k_1month (2 unique)-----
# accessto_13k_1month
# No     10630
# Yes    10241
#
# ---not_difficult (2 unique)-----
# not_difficult
# No     16337
# Yes     4534
#
# ---financial_status (3 unique)-----
# financial_status
# Worsened           10981
# Stayed the same     5609
# Improved            4281
#
# ---fl_score (4 unique)-----
# fl_score
# Two correct     8580
# All correct     8085
# One correct     3493
# None correct     713
#
# ---barriers_bank (9 unique)-----
# barriers_bank
# Affordability              10223
# Eligibility                 1499
# Relevance/Suitability       1159
# Access                      1045
# Awareness                    959
# Trust                        171
# Other                         36
# Charges/Product pricing       27
# Service quality               18
#
# ---has_disability (2 unique)-----
# has_disability
# Without Disability    19936
# With Disability         935
#
# ====================
# Numerical Values- Distributions
# ====================
#
# ---household_size---
# Min: <bound method Series.min of 0         5
# 1        11
# 2         2
# 3         1
# 4         1
#          ..
# 20866     8
# 20867     4
# 20868     6
# 20869     7
# 20870     3
# Name: household_size, Length: 20871, dtype: int64>
#  Max: 20,
#  Mean: 4.22,
#  Median: 4.00 ,
#  Std: 2.51
#
# ---monthly_income---
# Min: <bound method Series.min of 0        30000
# 1        10000
# 2         3000
# 3        10000
# 4        10000
#          ...
# 20866     6600
# 20867    10000
# 20868     6000
# 20869    13000
# 20870     5000
# Name: monthly_income, Length: 20871, dtype: int64>
#  Max: 200000,
#  Mean: 9702.77,
#  Median: 5000.00 ,
#  Std: 15423.37
#
# ---prodsum1---
# Min: <bound method Series.min of 0        3
# 1        1
# 2        5
# 3        4
# 4        5
#         ..
# 20866    2
# 20867    3
# 20868    4
# 20869    6
# 20870    0
# Name: prodsum1, Length: 20871, dtype: int64>
#  Max: 22,
#  Mean: 3.94,
#  Median: 3.00 ,
#  Std: 3.23
#
# ====================
# TARGET VARIABLE:financial_status
# ====================
# Column 'financial_status' not found
# Available columns: ['county', 'location_type', 'Sex', 'Age', 'household_size', 'education_level', 'marital_status', 'monthly_income', 'Savings_formal', 'Savings_informal', 'Loan_formal', 'Loan_informal', 'defaulted', 'formal_service_use', 'mobile_money_access', 'barriers_mobile_money', 'mobile_ownership_1', 'experienced_shock', 'nfhi_11', 'nfhi_12', 'nfhi_13', 'accessto_13k_1month', 'not_difficult', 'financial_status', 'fl_score', 'prodsum1', 'barriers_bank', 'has_disability']

# %%
##Removing quotes from string values
text_cols=df.select_dtypes(include=['object','category']).columns
for col in text_cols:
    df[col]=df[col].astype(str).str.strip().str.replace('""','',regex=False)

##Filling in blank values in Barriers_bank
df["barriers_bank"]= df['barriers_bank'].fillna('No barrier')
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Series([], dtype: int64)
